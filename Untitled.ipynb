# %%
import Credentials      # Get API keys, etc.
import pandas as pd
from pprint import pprint as pp

apikey = Credentials.apikey
baseurl = 'https://api-na.hosted.exlibrisgroup.com'
queryUpdateItem = '/almaws/v1/bibs/{mms_id}/holdings/{holding_id}/items/{item_pid}?apikey={apikey}'

# %%
### Get MMS/Holding/Item IDs, Descriptions, Locations from spreadsheet ###
print("Reading Excel file . . .")
df = pd.read_csv("FullItemList.csv", converters={'Item ID':str})
# Out:
# Reading Excel file . . .

# %%
df
# Out:
#                Permanent Location                     Call Number Item Policy  \
# 0                     2L Gov Docs                       AE 2.106:     Red Tag
# 1                     2L Gov Docs                       AE 2.106:     Red Tag
# 2                     2L Gov Docs                       AE 2.106:     Red Tag
# 3                     2L Gov Docs                       AE 2.106:     Red Tag
# 4                     2L Gov Docs                       AE 2.106:     Red Tag
# ...                           ...                             ...         ...
# 99995          LL Curriculum Coll               QA135.5 .R45 2003   Monograph
# 99996                   2L Stacks                      E664.R7 J5   Monograph
# 99997                   2L Stacks                      E664.R7 J5   Monograph
# 99998  LL Curriculum Meeting Room  MicFe E151 .L5 no.LAC 22358-60  Microfiche
# 99999  LL Curriculum Meeting Room  MicFe E151 .L5 no.LAC 22358-60  Microfiche
#
#       Material Type    Description            Item ID       Holdings ID  \
# 0             Issue          87/40  23128946300006388  2276563440006388
# 1             Issue          87/39  23128946290006388  2276563440006388
# 2             Issue          87/38  23128946280006388  2276563440006388
# 3             Issue          87/37  23128946270006388  2276563440006388
# 4             Issue          87/36  23128946260006388  2276563440006388
# ...             ...            ...                ...               ...
# 99995          Book            v.3   2364534610006388  2264534640006388
# 99996          Book            v.1   2364534400006388  2264534410006388
# 99997          Book            v.2   2364534390006388  2264534410006388
# 99998     Microform          v.1-2   2364533640006388  2264533650006388
# 99999     Microform  v.3-v.4 p.227   2364533630006388  2264533650006388
#
#                    MMS ID                           Type / Creator / Imprint  \
# 0      991003093289706388  Journal By United States. Office of the Federa...
# 1      991003093289706388  Journal By United States. Office of the Federa...
# 2      991003093289706388  Journal By United States. Office of the Federa...
# 3      991003093289706388  Journal By United States. Office of the Federa...
# 4      991003093289706388  Journal By United States. Office of the Federa...
# ...                   ...                                                ...
# 99995  991003010709706388  Book By Reimer, Wilbert. (Fresno, Calif. : AIM...
# 99996  991002691069706388  Book By Jessup, Philip C. (New York, Dodd, Mea...
# 99997  991002691069706388  Book By Jessup, Philip C. (New York, Dodd, Mea...
# 99998  991001149919706388  Book By Winthrop, Adam, ([Boston] : Massachuse...
# 99999  991001149919706388  Book By Winthrop, Adam, ([Boston] : Massachuse...
#
#                                                    Title
# 0                                       Federal register
# 1                                       Federal register
# 2                                       Federal register
# 3                                       Federal register
# 4                                       Federal register
# ...                                                  ...
# 99995  What's next?: using patterns to solve problems...
# 99996                 Elihu Root, by Philip C. Jessup ..
# 99997                 Elihu Root, by Philip C. Jessup ..
# 99998                     Winthrop papers ... 1498-1649.
# 99999                     Winthrop papers ... 1498-1649.
#
# [100000 rows x 10 columns]
